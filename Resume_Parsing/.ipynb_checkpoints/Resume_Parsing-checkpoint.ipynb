# %% [markdown]
# ## Pyresparser
#
# A simple resume parser used for extracting information from resumes
#
# ### Features
# - Extract name
# - Extract email
# - Extract mobile numbers
# - Extract skills
# - Extract total experience
# - Extract college name
# - Extract degree
# - Extract designation
# - Extract company names

# %%
pip install pyresparser
# Out:
# Requirement already satisfied: pyresparser in /Users/faizan/opt/anaconda3/lib/python3.7/site-packages (1.0.6)
# Requirement already satisfied: urllib3>=1.25.3 in /Users/faizan/opt/anaconda3/lib/python3.7/site-packages (from pyresparser) (1.25.8)
# Requirement already satisfied: pytz>=2019.1 in /Users/faizan/opt/anaconda3/lib/python3.7/site-packages (from pyresparser) (2019.3)
# Requirement already satisfied: six>=1.12.0 in /Users/faizan/opt/anaconda3/lib/python3.7/site-packages (from pyresparser) (1.14.0)
# Requirement already satisfied: spacy>=2.1.4 in /Users/faizan/opt/anaconda3/lib/python3.7/site-packages (from pyresparser) (2.3.4)
# Requirement already satisfied: python-dateutil>=2.8.0 in /Users/faizan/opt/anaconda3/lib/python3.7/site-packages (from pyresparser) (2.8.1)
# Requirement already satisfied: pycryptodome>=3.8.2 in /Users/faizan/opt/anaconda3/lib/python3.7/site-packages (from pyresparser) (3.9.9)
# Requirement already satisfied: wasabi>=0.2.2 in /Users/faizan/opt/anaconda3/lib/python3.7/site-packages (from pyresparser) (0.8.0)
# Requirement already satisfied: cymem>=2.0.2 in /Users/faizan/opt/anaconda3/lib/python3.7/site-packages (from pyresparser) (2.0.4)
# Requirement already satisfied: requests>=2.22.0 in /Users/faizan/opt/anaconda3/lib/python3.7/site-packages (from pyresparser) (2.22.0)
# Requirement already satisfied: pyrsistent>=0.15.2 in /Users/faizan/opt/anaconda3/lib/python3.7/site-packages (from pyresparser) (0.15.7)
# Requirement already satisfied: blis>=0.2.4 in /Users/faizan/opt/anaconda3/lib/python3.7/site-packages (from pyresparser) (0.7.3)
# Requirement already satisfied: thinc>=7.0.4 in /Users/faizan/opt/anaconda3/lib/python3.7/site-packages (from pyresparser) (7.4.3)
# Requirement already satisfied: chardet>=3.0.4 in /Users/faizan/opt/anaconda3/lib/python3.7/site-packages (from pyresparser) (3.0.4)
# Requirement already satisfied: pandas>=0.24.2 in /Users/faizan/opt/anaconda3/lib/python3.7/site-packages (from pyresparser) (1.0.1)
# Requirement already satisfied: pdfminer.six>=20181108 in /Users/faizan/opt/anaconda3/lib/python3.7/site-packages (from pyresparser) (20200517)
# Requirement already satisfied: nltk>=3.4.3 in /Users/faizan/opt/anaconda3/lib/python3.7/site-packages (from pyresparser) (3.4.5)
# Requirement already satisfied: idna>=2.8 in /Users/faizan/opt/anaconda3/lib/python3.7/site-packages (from pyresparser) (2.8)
# Requirement already satisfied: jsonschema>=3.0.1 in /Users/faizan/opt/anaconda3/lib/python3.7/site-packages (from pyresparser) (3.2.0)
# Requirement already satisfied: preshed>=2.0.1 in /Users/faizan/opt/anaconda3/lib/python3.7/site-packages (from pyresparser) (3.0.4)
# Requirement already satisfied: attrs>=19.1.0 in /Users/faizan/opt/anaconda3/lib/python3.7/site-packages (from pyresparser) (19.3.0)
# Requirement already satisfied: numpy>=1.16.4 in /Users/faizan/opt/anaconda3/lib/python3.7/site-packages (from pyresparser) (1.18.4)
# Requirement already satisfied: docx2txt>=0.7 in /Users/faizan/opt/anaconda3/lib/python3.7/site-packages (from pyresparser) (0.8)
# Requirement already satisfied: tqdm>=4.32.2 in /Users/faizan/opt/anaconda3/lib/python3.7/site-packages (from pyresparser) (4.46.0)
# Requirement already satisfied: sortedcontainers>=2.1.0 in /Users/faizan/opt/anaconda3/lib/python3.7/site-packages (from pyresparser) (2.1.0)
# Requirement already satisfied: srsly>=0.0.7 in /Users/faizan/opt/anaconda3/lib/python3.7/site-packages (from pyresparser) (2.3.2)
# Requirement already satisfied: certifi>=2019.6.16 in /Users/faizan/opt/anaconda3/lib/python3.7/site-packages (from pyresparser) (2019.11.28)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /Users/faizan/opt/anaconda3/lib/python3.7/site-packages (from spacy>=2.1.4->pyresparser) (1.0.4)
# Requirement already satisfied: catalogue<1.1.0,>=0.0.7 in /Users/faizan/opt/anaconda3/lib/python3.7/site-packages (from spacy>=2.1.4->pyresparser) (1.0.0)
# Requirement already satisfied: plac<1.2.0,>=0.9.6 in /Users/faizan/opt/anaconda3/lib/python3.7/site-packages (from spacy>=2.1.4->pyresparser) (1.1.3)
# Requirement already satisfied: setuptools in /Users/faizan/opt/anaconda3/lib/python3.7/site-packages (from spacy>=2.1.4->pyresparser) (46.0.0.post20200309)
# Requirement already satisfied: importlib-metadata; python_version < "3.8" in /Users/faizan/opt/anaconda3/lib/python3.7/site-packages (from jsonschema>=3.0.1->pyresparser) (1.5.0)
# Requirement already satisfied: zipp>=0.5 in /Users/faizan/opt/anaconda3/lib/python3.7/site-packages (from importlib-metadata; python_version < "3.8"->jsonschema>=3.0.1->pyresparser) (2.2.0)
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# For NLP operations we use spacy and nltk.

# %%
#spaCy
#python -m spacy download en_core_web_sm

#nltk
#python -m nltk.downloader words

# %%
from pyresparser import ResumeParser
import pandas as pd

# %%
list_resumes=[]

# %%
import os
from fnmatch import fnmatch

root = '/Users/faizan/Documents/BASF_Challange/Resume_Parsing/Resumes'
pattern = "*.docx"

for path, subdirs, files in os.walk(root):
    for name in files:
        if fnmatch(name, pattern):
            #print (os.path.join(name))
            list_resumes.append(ResumeParser('/Users/faizan/Documents/BASF_Challange/Resume_Parsing/Resumes/%s' % os.path.join(name)).get_extracted_data())

# %%
#Creating dataframe from dictonaries
df = pd.DataFrame(list_resumes)

# %%
df
# Out:
#                                                   name  \
# 0                                       Venkat N Phone
# 1    2                                             ...
# 2                                          Jennifer M.
# 3                                         Jagan S Iyer
# 4                                          RESUME RAMA
# ..                                                 ...
# 219                               CHENNA KESAVA Phone:
# 220                                         Venkata Sr
# 221                                            Ashok A
# 222                                      Navneet Gupta
# 223                                     VISHNU J Email
#
#                                email mobile_number  \
# 0                vhealthba@gmail.com  314-662-2902
# 1        Shashank.tiwari44@gmail.com      600-1785
# 2                               None          None
# 3           jagansrconsult@gmail.com      412-1658
# 4     NANDYALARAMAKARTHIK1@GMAIL.COM      858-6880
# ..                               ...           ...
# 219        chennakesava231@gmail.com  469-677-7837
# 220         venkata.s.k310@gmail.com      247-2160
# 221          ashtechjava12@gmail.com      681-4217
# 222     richard@sonussoftwareinc.com       1851131
# 223  jammigumpulavishnu452@gmail.com      655-4689
#
#                                                 skills college_name  \
# 0    [Contracts, Payroll, Recruitment, Sap, Vendor ...         None
# 1    [Contracts, Salesforce, International, Sap, Kp...         None
# 2    [Mysql, Nosql, Security, Css, Sql server, Desi...         None
# 3    [Ms project, Pl/sql, Variances, Negotiation, C...         None
# 4    [Profiling, Css, Payroll, Json, Operations, Co...         None
# ..                                                 ...          ...
# 219  [Algorithms, Css, International, Scheduling, P...         None
# 220  [Prototype, Technical skills, Positioning, Mys...         None
# 221  [Pl/sql, Troubleshooting, Security, Contracts,...         None
# 222  [Contracts, Css, Scheduling, Application suppo...         None
# 223  [Css, Scheduling, Presentation, Parser, Json, ...         None
#
#                                                 degree  \
# 0                                                 None
# 1    [Post Graduate Diploma in Management.    Appli...
# 2                 [Bachelor of Electronic Engineering]
# 3    [Master of Science in Physics, Bachelor of Sci...
# 4                                                 None
# ..                                                 ...
# 219                                               None
# 220                                               None
# 221                                               None
# 222           [Bachelors of Technology from IIT Delhi]
# 223                                               None
#
#                                            designation experience  \
# 0                                   [Business Analyst]       None
# 1                                   [Business Analyst]       None
# 2    [Sr. Java Developer/Architect Proven self-moti...         []
# 3                                                 None       None
# 4                                                 None       None
# ..                                                 ...        ...
# 219                                     [Area Manager]       None
# 220                                               None       None
# 221                                               None       None
# 222                           [Database Architect/DBA]       None
# 223  [Programmer Analyst and Software Engineer, Sen...       None
#
#                       company_names no_of_pages  total_experience
# 0               [Microsoft, Oracle]        None               0.0
# 1         [Shashank Tiwari, Oracle]        None               0.0
# 2                          [Oracle]        None               0.0
# 3                             [F2F]        None               0.0
# 4                              None        None               0.0
# ..                              ...         ...               ...
# 219                        [Oracle]        None               0.0
# 220                        [Oracle]        None               0.0
# 221  [Accenture, Microsoft, Oracle]        None               0.0
# 222             [Microsoft, Oracle]        None               0.0
# 223                        [Oracle]        None               0.0
#
# [224 rows x 11 columns]

# %%
df.to_csv(index=True)
# Out:
# ',name,email,mobile_number,skills,college_name,degree,designation,experience,company_names,no_of_pages,total_experience\n0,Venkat N Phone,vhealthba@gmail.com,314-662-2902,"[\'Contracts\', \'Payroll\', \'Recruitment\', \'Sap\', \'Vendor management\', \'Sharepoint\', \'Operations\', \'Specifications\', \'Cloud\', \'Requests\', \'Public relations\', \'Microsoft visio\', \'Modeling\', \'Test cases\', \'Invoicing\', \'Talent management\', \'Powerpoint\', \'Schedule\', \'Six sigma\', \'Email\', \'Sql\', \'System\', \'Mobile\', \'Marketing\', \'Conversion\', \'Word\', \'Improvement\', \'Communication\', \'Business analysis\', \'Scrum\', \'Staffing\', \'Windows\', \'Sales\', \'Access\', \'Test plans\', \'Usability\', \'Microsoft word\', \'Workflows\', \'Schedules\', \'Reporting\', \'User experience\', \'Deposits\', \'Hp alm\', \'Asset management\', \'Peoplesoft\', \'Brand\', \'Agile\', \'Documentation\', \'Jira\', \'Gap analysis\', \'Operating systems\', \'Oracle\', \'Updates\', \'Shell\', \'Strategy\', \'Healthcare\', \'Training\', \'Health\', \'Automation\', \'Internal stakeholders\', \'Plan\', \'Erp\', \'Visio\', \'Technical skills\', \'Security\', \'Design\', \'Process\', \'Sdlc\', \'Testing\', \'Recruiting\', \'Billing\', \'Analysis\', \'Hospital\', \'Database\', \'Workflow\', \'Analytical\', \'Matrix\', \'Engineering\', \'Microsoft office\', \'Technical\', \'Excel\', \'Etl\', \'Sourcing\', \'Travel\', \'Banking\']",,,[\'Business Analyst\'],,"[\'Microsoft\', \'Oracle\']",,0.0\n1,2                                                                                                                                                                                         ,Shashank.tiwari44@gmail.com,600-1785,"[\'Contracts\', \'Salesforce\', \'International\', \'Sap\', \'Kpi\', \'Data analysis\', \'Sharepoint\', \'Operations\', \'Statistics\', \'Vendors\', \'Specifications\', \'Research\', \'Itil\', \'Reports\', \'Tableau\', \'Requests\', \'Metrics\', \'Active directory\', \'Modeling\', \'Test cases\', \'Policies\', \'Ms project\', \'Powerpoint\', \'Product owner\', \'Sql server\', \'Six sigma\', \'Sql\', \'System\', \'Architecture\', \'Word\', \'Improvement\', \'Certification\', \'Business analysis\', \'Scrum\', \'Sales\', \'Access\', \'Test plans\', \'Schedules\', \'Reporting\', \'Asset management\', \'Ply\', \'Administration\', \'User stories\', \'Agile\', \'Documentation\', \'Ms excel\', \'Jira\', \'Business process\', \'Gap analysis\', \'Warehouse\', \'Oracle\', \'Drafting\', \'Strategy\', \'Training\', \'Queries\', \'Plan\', \'Visio\', \'Erp\', \'Security\', \'Design\', \'Process\', \'Sdlc\', \'Writing\', \'Testing\', \'Jad\', \'Analysis\', \'Compliance\', \'Database\', \'Performance metrics\', \'Technical issues\', \'Workflow\', \'Crm\', \'Benchmarking\', \'Matrix\', \'Engineering\', \'Process improvement\', \'Technical\', \'Excel\', \'Sourcing\', \'Business intelligence\', \'Root cause\']",,"[\'Post Graduate Diploma in Management.    Application platforms & Environments: Databases              Oracle\', \'Bachelor in Science\', \'Masters -Business Administration\', \'MBA\']",[\'Business Analyst\'],,"[\'Shashank Tiwari\', \'Oracle\']",,0.0\n2,Jennifer M.,,,"[\'Mysql\', \'Nosql\', \'Security\', \'Css\', \'Sql server\', \'Design\', \'Front-end\', \'Sql\', \'System\', \'Architecture\', \'Json\', \'Html\', \'Video\', \'Improvement\', \'Apis\', \'Content\', \'Communication\', \'Analysis\', \'Xml\', \'Oracle\', \'Windows\', \'Database\', \'Html5\', \'Ui\', \'Aws\', \'Unix\', \'Api\', \'C++\', \'Javascript\', \'Cloud\', \'Access\', \'Strategy\', \'Scripting\', \'Engineering\', \'Rest\', \'Fda\', \'Technical\', \'Linux\', \'Java\', \'Web services\', \'Soap\', \'Sketch\']",,[\'Bachelor of Electronic Engineering\'],"[\'Sr. Java Developer/Architect Proven self-motivate, self-learning and self-improvement and problem solving ability.  Achievements in REST\', \'Technical Lead\', \'Principal Engineer\']",[],[\'Oracle\'],,0.0\n3,Jagan S Iyer,jagans ...

# %%
compression_opts = dict(method='zip', archive_name='data.csv')  

df.to_csv('data.zip', index=False, compression=compression_opts)
